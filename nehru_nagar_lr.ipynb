# %%
import pandas as pd
df=pd.DataFrame()

# %%
df=pd.read_csv('nehrunagar.csv', index_col='date',parse_dates=True)
# Out:
# <ipython-input-189-389477ab6b06>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df=pd.read_csv('nehrunagar.csv', index_col='date',parse_dates=True)

# %%
df.columns = ['population']
df.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='date'>

# %%
df['population_LastMonth']=df['population'].shift(+1)
df['population_2Monthsback']=df['population'].shift(+2)
df['population_3Monthsback']=df['population'].shift(+3)
df
# Out:
#             population  population_LastMonth  population_2Monthsback  \
# date
# 2022-01-30          41                   NaN                     NaN
# 2022-03-21          46                  41.0                     NaN
# 2022-11-04          43                  46.0                    41.0
# 2022-02-06          47                  43.0                    46.0
# 2022-07-23          49                  47.0                    43.0
# 2022-04-09          57                  49.0                    47.0
# 2022-05-11          53                  57.0                    49.0
# 2022-12-16          49                  53.0                    57.0
# 2023-07-01          47                  49.0                    53.0
# 2023-02-02          48                  47.0                    49.0
# 2022-02-19          45                  48.0                    47.0
#
#             population_3Monthsback
# date
# 2022-01-30                     NaN
# 2022-03-21                     NaN
# 2022-11-04                     NaN
# 2022-02-06                    41.0
# 2022-07-23                    46.0
# 2022-04-09                    43.0
# 2022-05-11                    47.0
# 2022-12-16                    49.0
# 2023-07-01                    57.0
# 2023-02-02                    53.0
# 2022-02-19                    49.0

# %%
df=df.dropna()
df
# Out:
#             population  population_LastMonth  population_2Monthsback  \
# date
# 2022-02-06          47                  43.0                    46.0
# 2022-07-23          49                  47.0                    43.0
# 2022-04-09          57                  49.0                    47.0
# 2022-05-11          53                  57.0                    49.0
# 2022-12-16          49                  53.0                    57.0
# 2023-07-01          47                  49.0                    53.0
# 2023-02-02          48                  47.0                    49.0
# 2022-02-19          45                  48.0                    47.0
#
#             population_3Monthsback
# date
# 2022-02-06                    41.0
# 2022-07-23                    46.0
# 2022-04-09                    43.0
# 2022-05-11                    47.0
# 2022-12-16                    49.0
# 2023-07-01                    57.0
# 2023-02-02                    53.0
# 2022-02-19                    49.0

# %%
from sklearn.linear_model import LinearRegression
lin_model=LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=100,max_features=3, random_state=1)

# %%
import numpy as np
x1,x2,x3,y=df['population_LastMonth'],df['population_2Monthsback'],df['population_3Monthsback'],df['population']
x1,x2,x3,y=np.array(x1),np.array(x2),np.array(x3),np.array(y)
x1,x2,x3,y=x1.reshape(-1,1),x2.reshape(-1,1),x3.reshape(-1,1),y.reshape(-1,1)
final_x=np.concatenate((x1,x2,x3),axis=1)
print(final_x)
# Out:
# [[43. 46. 41.]
#  [47. 43. 46.]
#  [49. 47. 43.]
#  [57. 49. 47.]
#  [53. 57. 49.]
#  [49. 53. 57.]
#  [47. 49. 53.]
#  [48. 47. 49.]]

# %%
X_train,X_test,y_train,y_test=final_x[1:14],final_x[1:14],y[1:16],y[1:16]
print(X_train.shape)
print(y_train.shape)
# Out:
# (7, 3)
# (7, 1)

# %%
lin_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lin_pred=lin_model.predict(X_test)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(lin_pred,label='Linear_Regression_Predictions')
plt.plot(y_test,label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse_lr=sqrt(mean_squared_error(lin_pred,y_test))

# %%
print('Mean Squared Error for Linear Regression Model is:',rmse_lr)
# Out:
# Mean Squared Error for Linear Regression Model is: 2.547467682380985
